# %%
info = {
    'name': 'Ali Khan',
    'age': 20,
     
}

# %%
info['some']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 info['some']
#
# KeyError: 'some'

# %%
info.get('nsomee')

# %%
info.name
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 info.name
#
# AttributeError: 'dict' object has no attribute 'name'

# %%
from box import ConfigBox
new_dic = ConfigBox(info)

# %%
new_dic
# Out:
# ConfigBox({'name': 'Ali Khan', 'age': 20})

# %%
new_dic.name
# Out:
# 'Ali Khan'

# %%
new_dic.age
# Out:
# 20

# %%
def normalfun(x, y):
    return x + y

# %%
normalfun(2,3.3)
# Out:
# 5.3

# %%
normalfun(3.3,2)
# Out:
# 5.3

# %%
normalfun(3.3, 3.3)
# Out:
# 6.6

# %%
from ensure import ensure_annotations

@ensure_annotations
def somefunction(x: int, y: float) -> float:
return x + y

# %%
f(1, 2.3)
# Out:
# 3.3

# %%
   
f(1, 2)
# Out:
# ---------------------------------------------------------------------------
# EnsureError                               Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 f(1, 2)
#
# File ~/Documents/GitHub/project1/venv/lib/python3.10/site-packages/ensure/main.py:870, in WrappedFunctionReturn.__call__(self, *args, **kwargs)
#     868     if not isinstance(value, templ):
#     869         msg = "Argument {arg} of type {valt} to {f} " "does not match annotation type {t}"
# --> 870         raise EnsureError(msg.format(arg=arg, f=self.f, t=templ, valt=type(value)))
#     872 return_val = self.f(*args, **kwargs)
#     873 if not isinstance(return_val, self.return_templ):
#
# EnsureError: Argument y of type <class 'int'> to <function f at 0x7a21a630a200> does not match annotation type <class 'float'>
